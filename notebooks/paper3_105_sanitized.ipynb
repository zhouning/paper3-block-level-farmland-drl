# %%
# Cell 1: Mount Drive & unpack
from google.colab import drive
drive.mount('/content/drive')
# !cp /content/drive/MyDrive/paper3_colab.zip /content/
# %cd /content
# !unzip -qo paper3_colab.zip

# %%
 # Cell 2: Install dependencies
# !pip install -q geopandas libpysal sb3-contrib shimmy tqdm

# %%
# !python colab_train_all.py --township 500227105

# %%
# Cell 4: Copy results back to Drive
# !cp -r results_real/blocks /content/drive/MyDrive/paper3_results/

# %%
# !python colab_train_all.py --township 500227105 --eval-only --summary-only
